# %% [markdown]
# <a href="https://colab.research.google.com/github/raguram/eva/blob/master/S5/5-MNIST-ImprovedModelArchitecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Install the dependencies

# %%
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.6/dist-packages (1.5.1)

# %% [markdown]
# ### Import dependencies

# %%
import torch
import torch.nn as nn
from torchvision import datasets, transforms
import torch.nn.functional as F
from torchsummary import summary
from tqdm import tqdm_notebook as tqdm
import torch.optim as optim
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np

# %% [markdown]
# ### Helper utilities

# %%
def isCuda():
  return torch.cuda.is_available()

def randInt(min, max, size): 
  return torch.LongTensor(size).random_(min, max)

def getDevice(): 
  return torch.device("cuda" if isCuda() else "cpu")

def showImages(images, labels, cols=10): 
  figure = plt.figure()
  num_of_images = len(images)
  rows = np.ceil(num_of_images/float(cols))
  for index in range(0, num_of_images):
    plt.subplot(rows, cols, index + 1)
    plt.axis('off')
    plt.imshow(images[index].numpy().squeeze(), cmap='gray_r') 

cpu = torch.device("cpu")
device = getDevice()
print(f'\nDevice: {device}')

# Set seed 
seed =1 
torch.manual_seed(seed)
if isCuda():
  torch.cuda.manual_seed(seed)
# Out:
# Device: cuda

# %% [markdown]
# ### Transformations for Train and Test

# %%
def train_transformations(): 
  return transforms.Compose([
                    transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
  
def test_transformations(): 
  return transforms.Compose([
                    transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])

# %% [markdown]
# ### Load train and test data

# %%
dataloader_args = dict(shuffle=True, batch_size=128, num_workers=4, pin_memory=True) if isCuda() else dict(shuffle=True, batch_size=64)

train_data = datasets.MNIST("../data", train=True, transform=train_transformations(), download=True)
train_loader = torch.utils.data.DataLoader(train_data, **dataloader_args)

test_data = datasets.MNIST("../data", train=False, transform=test_transformations(), download=True)
test_loader = torch.utils.data.DataLoader(test_data, **dataloader_args)

print(f'\nSize of train data:{train_data.data.shape}')
print(f'\nSize of test data:{test_data.data.shape}')
# Out:
# Size of train data:torch.Size([60000, 28, 28])
#
# Size of test data:torch.Size([10000, 28, 28])

# %% [markdown]
# ### View training/test data and their statistics

# %%
randImages = randInt(0, len(test_data.data), 50)
showImages(test_data.data[randImages], test_data.targets[randImages])

# %% [markdown]
# ### Network architecture

# %%
class Net(nn.Module): 

  def __init__(self): 
    super(Net, self).__init__()

    self.conv1 = nn.Sequential(
        nn.Conv2d(1, 10, 3, padding=0, bias=False), 
        nn.ReLU(), 
        nn.BatchNorm2d(10),
        nn.Dropout2d(0.04),
        nn.Conv2d(10, 16, 3, padding=0, bias=False), 
        nn.ReLU(),
        nn.BatchNorm2d(16),
        nn.Dropout2d(0.04)
    ) # Output - 24 x 24

    self.transition1 = nn.Sequential(
        nn.Conv2d(16, 8, 1, padding=0, bias=False),
        nn.MaxPool2d(2, 2)
    ) # Output - 14 x 14 

    self.conv2 = nn.Sequential(
        nn.Conv2d(8, 16, 3, padding=0, bias=False), 
        nn.ReLU(),
        nn.BatchNorm2d(16),
        nn.Dropout2d(0.04),
        nn.Conv2d(16, 16, 3, padding=0, bias=False), 
        nn.ReLU(),
        nn.BatchNorm2d(16),
        nn.Dropout2d(0.04),
        nn.Conv2d(16, 16, 3, padding=0, bias=False), 
        nn.ReLU(),
        nn.BatchNorm2d(16),
        nn.Dropout2d(0.04),
        nn.Conv2d(16, 15, 3, padding=0, bias=False), 
        nn.ReLU()
    ) # output = 6 x 6

    self.gap1 = nn.AdaptiveAvgPool2d(1)
    self.conv4 = nn.Conv2d(15, 10, 1, bias=False)

  def forward(self, x): 

    x = self.transition1(self.conv1(x))
    x = self.conv2(x)
    x = self.conv4(self.gap1(x))
    x = x.view(-1, 10)
    return F.log_softmax(x)

  def summarize(self, input): 
    summary(self, input_size=input)

Net().to(getDevice()).summarize((1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 10, 26, 26]              90
#               ReLU-2           [-1, 10, 26, 26]               0
#        BatchNorm2d-3           [-1, 10, 26, 26]              20
#          Dropout2d-4           [-1, 10, 26, 26]               0
#             Conv2d-5           [-1, 16, 24, 24]           1,440
#               ReLU-6           [-1, 16, 24, 24]               0
#        BatchNorm2d-7           [-1, 16, 24, 24]              32
#          Dropout2d-8           [-1, 16, 24, 24]               0
#             Conv2d-9            [-1, 8, 24, 24]             128
#         MaxPool2d-10            [-1, 8, 12, 12]               0
#            Conv2d-11           [-1, 16, 10, 10]           1,152
#              ReLU-12           [-1, 16, 10, 10]               0
#       BatchNorm2d-13           [-1, 16, 10, 10]              32
#         Dropout2d-14           [-1, 16, 10, 10]               0
#            Conv2d-15             [-1, 16, 8, 8]           2,304
#              ReLU-16             [-1, 16, 8, 8]               0
#       BatchNorm2d-17             [-1, 16, 8, 8]              32
#         Dropout2d-18             [-1, 16, 8, 8]               0
#            Conv2d-19             [-1, 16, 6, 6]           2,304
#              ReLU-20             [-1, 16, 6, 6]               0
#       BatchNorm2d-21             [-1, 16, 6, 6]              32
#         Dropout2d-22             [-1, 16, 6, 6]               0
#            Conv2d-23             [-1, 15, 4, 4]           2,160
#              ReLU-24             [-1, 15, 4, 4]               0
# AdaptiveAvgPool2d-25             [-1, 15, 1, 1]               0
#            Conv2d-26             [-1, 10, 1, 1]             150
# ================================================================
# Total params: 9,876
# Trainable params: 9,876
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.63
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.67
# ----------------------------------------------------------------
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.

# %% [markdown]
# ### Utilities to compute metrics

# %%
def compute_accuracy(prediction, target): 
  return 100 * prediction.eq(target.view_as(prediction)).sum().item() / float(len(prediction))

def compute_metrics(data, prediction, target): 
  corrects = prediction.eq(target.view_as(prediction))
  accuracy = corrects.sum().item() / len(prediction)
  miss_indices = ~corrects
  miss_data = data[miss_indices]  
  miss_predictions = prediction[miss_indices]
  miss_targets = target[miss_indices]
  print(confusion_matrix(target.to(cpu), prediction.to(cpu)))
  return accuracy * 100, (miss_data, miss_predictions, miss_targets)

# %% [markdown]
# ### Code to train the model

# %%
def train_one_batch(model, data, target, optimizer): 
  optimizer.zero_grad()
  output = model(data)
  loss = F.nll_loss(output, target)
  loss.backward()
  optimizer.step()
  return (loss, output.argmax(dim=1))

def train_one_epoch(model, train_loader, optimizer, device=getDevice()): 
  model.train()
  pbar = tqdm(train_loader, ncols=1000) 
  wholePred = []
  wholeData = []
  wholeTarget = []
  for idx, (data, target) in enumerate(pbar): 
    data, target = data.to(device), target.to(device)
    (loss, prediction) = train_one_batch(model, data, target, optimizer)
    accuracy = compute_accuracy(prediction, target)
    pbar.set_description(desc= f'Loss={loss.item()}\t id={idx}\t accuracy={accuracy}')
    wholePred.append(prediction)
    wholeData.append(data)
    wholeTarget.append(target)
  return (torch.cat(wholeData), torch.cat(wholeTarget), torch.cat(wholePred))

# %% [markdown]
# ### Code to test the model

# %%
def test_one_batch(model, data, target): 
  output = model(data)
  loss = F.nll_loss(output, target)  
  return (loss, output.argmax(dim=1))
  
def test(model, test_loader, device=getDevice()): 
  model.eval()
  pbar = tqdm(test_loader, ncols=1000)
  wholePred = []
  wholeData = []
  wholeTarget = []
  with torch.no_grad(): 
    for idx, (data, target) in enumerate(pbar): 
      data, target = data.to(device), target.to(device)
      (loss, prediction) = test_one_batch(model, data, target)
      accuracy = compute_accuracy(prediction, target)
      pbar.set_description(desc= f'Loss={loss.item()}\t id={idx}\t accuracy={accuracy}%')
      wholePred.append(prediction)
      wholeData.append(data)
      wholeTarget.append(target)
  return (torch.cat(wholeData), torch.cat(wholeTarget), torch.cat(wholePred))

# %% [markdown]
# ### Build the model by training and testing.

# %%
def build(model, train_loader, optimizer, epoch):
  train_accs = []
  test_accs = [] 
  for e in range(0, epoch): 
    print(f'\n\nEpoch: {e + 1}')
    (train_data, train_target, train_prediction) = train_one_epoch(model, train_loader, optimizer)
    trainAcc = compute_accuracy(train_prediction, train_target)
    train_accs.append(trainAcc)
    print(f'Train Accuracy: {trainAcc}%')
    (test_data, test_target, test_prediction) = test(net, test_loader)
    testAcc = compute_accuracy(test_prediction, test_target)
    test_accs.append(testAcc)
    print(f'Test Accuracy: {testAcc}%')
  return(train_accs, test_accs)

net = Net().to(getDevice())
optimizer = optim.SGD(net.parameters(), lr = 0.01, momentum=0.9)
(train_accs, test_accs) = build(net, train_loader, optimizer, 15)
# Out:
# Epoch: 1
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Accuracy: 85.05166666666666%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 97.64%
#
#
# Epoch: 2
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# Train Accuracy: 97.67333333333333%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 98.78%
#
#
# Epoch: 3
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# Train Accuracy: 98.16166666666666%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 98.96%
#
#
# Epoch: 4
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# Train Accuracy: 98.49333333333334%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 99.03%
#
#
# Epoch: 5
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# Train Accuracy: 98.63333333333334%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 98.99%
#
#
# Epoch: 6
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# Train Accuracy: 98.70833333333333%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 99.32%
#
#
# Epoch: 7
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# Train Accuracy: 98.87333333333333%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 99.1%
#
#
# Epoch: 8
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# Train Accuracy: 98.95833333333333%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 99.32%
#
#
# Epoch: 9
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# Train Accuracy: 98.92166666666667%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 99.1%
#
#
# Epoch: 10
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# Train Accuracy: 99.00833333333334%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 99.35%
#
#
# Epoch: 11
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# Train Accuracy: 99.11666666666666%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 99.34%
#
#
# Epoch: 12
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# Train Accuracy: 99.10333333333334%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 99.39%
#
#
# Epoch: 13
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# Train Accuracy: 99.105%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 99.28%
#
#
# Epoch: 14
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# Train Accuracy: 99.18166666666667%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 99.38%
#
#
# Epoch: 15
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=469), HTML(value='')), layout=Layout(display=…
# Train Accuracy: 99.205%
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=79), HTML(value='')), layout=Layout(display='…
# Test Accuracy: 99.49%

# %%
fig, axs = plt.subplots(1,2,figsize=(10, 5))
axs[0].plot(train_accs)
axs[0].set_title("Training Accuracy")
axs[1].plot(test_accs)
axs[1].set_title("Test Accuracy")
# Out:
# Text(0.5, 1.0, 'Test Accuracy')

# %% [markdown]
# ## Target
#
# Target is to increase the capacity of the model by tweaking the layers a bit. I removed out the second max pool layer and added more conv layers and removed out padding motivated by the EVA4S5F8 model architecture.
#
# ## Result
#
# * Parameters = 9,876
# * Best train accuracy = 99.205%
# * Best validation accuracy = 99.49%
#
# ## Analysis
#
# * Model is not overfitting.
# * The test accuracy hit 99.49% only once and is not consistent. We can still improve the model.
